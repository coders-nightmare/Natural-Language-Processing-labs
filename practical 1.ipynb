# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
import nltk

# %%
df=pd.read_csv("2010-capitalbikeshare-tripdata.csv")
df
# Out:
#         Duration        Start date          End date  Start station number  \
# 0           1012  20-09-2010 11:27  20-09-2010 11:43                 31208
# 1             61  20-09-2010 11:41  20-09-2010 11:42                 31209
# 2           2690  20-09-2010 12:05  20-09-2010 12:50                 31600
# 3           1406  20-09-2010 12:06  20-09-2010 12:29                 31600
# 4           1413  20-09-2010 12:10  20-09-2010 12:34                 31100
# ...          ...               ...               ...                   ...
# 115592      2179  31-12-2010 23:20  31-12-2010 23:56                 31110
# 115593       953  31-12-2010 23:21  31-12-2010 23:37                 31106
# 115594       737  31-12-2010 23:27  31-12-2010 23:39                 31602
# 115595       514  31-12-2010 23:37  31-12-2010 23:46                 31111
# 115596     51962  31-12-2010 23:49  01-01-2011 14:15                 31111
#
#                         Start station  End station number  \
# ...

# %%
df.columns
# Out:
# Index(['Duration', 'Start date', 'End date', 'Start station number',
#        'Start station', 'End station number', 'End station', 'Bike number',
#        'Member type'],
#       dtype='object')

# %%
df.describe()
# Out:
#             Duration  Start station number  End station number
# count  115597.000000         115597.000000       115597.000000
# mean     1254.649956          31266.213431        31268.042250
# std      2914.317998            187.645048          186.194316
# min        60.000000          31000.000000        31000.000000
# 25%       403.000000          31110.000000        31111.000000
# 50%       665.000000          31213.000000        31214.000000
# 75%      1120.000000          31301.000000        31238.000000
# max     85644.000000          31805.000000        31805.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 115597 entries, 0 to 115596
# Data columns (total 9 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   Duration              115597 non-null  int64
#  1   Start date            115597 non-null  object
#  2   End date              115597 non-null  object
#  3   Start station number  115597 non-null  int64
#  4   Start station         115597 non-null  object
#  5   End station number    115597 non-null  int64
#  6   End station           115597 non-null  object
#  7   Bike number           115597 non-null  object
#  8   Member type           115597 non-null  object
# dtypes: int64(3), object(6)
# memory usage: 7.9+ MB

# %%
df['Start station'].unique()
# Out:
# array(['M St & New Jersey Ave SE', '1st & N St  SE', '5th & K St NW',
#        '19th St & Pennsylvania Ave NW', '7th & T St NW', '10th & U St NW',
#        'Minnesota Ave Metro/DOES', '4th & W St NE', '1st & M St NE',
#        'Park Rd & Holmead Pl NW', '14th & Harvard St NW',
#        '14th & V St NW', '16th & Harvard St NW', '19th & E Street NW',
#        '20th & Crystal Dr', '21st & I St NW', '15th & P St NW',
#        '27th & Crystal Dr', 'Calvert & Biltmore St NW',
#        'Massachusetts Ave & Dupont Circle NW',
#        'Adams Mill & Columbia Rd NW', '23rd & Crystal Dr',
#        'Eads St & 15th St S', '14th & R St NW', '21st & M St NW',
#        '15th & Crystal Dr', 'Good Hope Rd & MLK Ave SE', '4th & M St SW',
#        '14th & Rhode Island Ave NW', '20th & E St NW', '18th & Eads St.',
#        '20th St & Florida Ave NW', '14th St & Spring Rd NW',
#        'Georgia Ave and Fairmont St NW',
#        'Pentagon City Metro / 12th & S Hayes St',
# ...

# %%
df['Start Station Lower']=df['Start station'].str.lower()

# %%
df['End Station Lower']=df['End station'].str.lower()

# %%
df.head()
# Out:
#    Duration        Start date          End date  Start station number  \
# 0      1012  20-09-2010 11:27  20-09-2010 11:43                 31208
# 1        61  20-09-2010 11:41  20-09-2010 11:42                 31209
# 2      2690  20-09-2010 12:05  20-09-2010 12:50                 31600
# 3      1406  20-09-2010 12:06  20-09-2010 12:29                 31600
# 4      1413  20-09-2010 12:10  20-09-2010 12:34                 31100
#
#                    Start station  End station number  \
# 0       M St & New Jersey Ave SE               31108
# 1                 1st & N St  SE               31209
# 2                  5th & K St NW               31100
# 3                  5th & K St NW               31602
# 4  19th St & Pennsylvania Ave NW               31201
#
#                      End station Bike number Member type  \
# 0                  4th & M St SW      W00742      Member
# 1                 1st & N St  SE      W00032      Member
# ...

# %%
df['Member type'].unique()
# Out:
# array(['Member', 'Casual', 'Unknown'], dtype=object)
